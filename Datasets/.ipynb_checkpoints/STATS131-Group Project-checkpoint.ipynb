# %% [markdown]
# ## STATS 131 - Group Project
# Created by Kaixin Wang
# ### Datasets:
# * GDP_and_GDP_Per_Capita.csv (1)
# * Expenditure_on_Health.csv (2)
# * Production_Trade_and_Supply_of_Energy.csv (3)
# * Internet_Usage.csv (4)
# * Public_Expenditure_on_Education.csv (5)
# * Tourist_Visitors_Arrival_and_Expenditure.csv (6)
# * GDP_on_R&D.csv (7)
# * Exchange_Rates.csv (8)
# * Consumer_Price_Index.csv (9)
#
# ### Variables:
# * response: CPI (9)
# * predictors:
#     - GDP (1)
#     - expenditure on health (2)
#     - energy usage (3)
#     - Internet usage (4)
#     - expenditure on education (5)
#     - expenditure on tourism (6)
#     - expenditure on science & technology (7)
#     - exchange rate (8)
#
# ### Dataset sources:
# United Nations: http://data.un.org/
# - National accounts (1)
#     - GDP and GDP per capita
# - Nutrition and health (2)
#     - Health expenditure
# - Energy (3)
#     - Energy production, trade and consumption
# - Communication (4)
#     - Internet usage
# - Education (5)
#     - Public expenditure on education
# - Science and technology (7)
#     - Human resources in R & D
# - Finance (8)
#     - Exchange rates
# - Price and production indices (9)
#     - Consumer price indices
#
# ### Objective:
# To predict the CPI (customer price index) of a country by using predictors that are elements of economic growth.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
CPI = pd.read_csv("Consumer_Price_Index.csv", encoding ="ISO-8859-1")
CPI.Series.unique()  # to extra certain rows
CPI = CPI.loc[CPI.Series == 'Consumer price index: General']
CPI.head()
# Out:
#    ID      Country  Year                         Series  Value
# 0   4  Afghanistan  2005  Consumer price index: General   71.1
# 1   4  Afghanistan  2010  Consumer price index: General    100
# 2   4  Afghanistan  2014  Consumer price index: General  133.1
# 3   4  Afghanistan  2015  Consumer price index: General  132.1
# 4   4  Afghanistan  2016  Consumer price index: General  137.9

# %%
health = pd.read_csv("Expenditure_on_Health.csv", encoding ="ISO-8859-1")

health = health.loc[health.Series == 'Current health expenditure (% of GDP)']
health.head()
# Out:
#    ID      Country  Year                                 Series  Value
# 0   4  Afghanistan  2005  Current health expenditure (% of GDP)    9.9
# 1   4  Afghanistan  2010  Current health expenditure (% of GDP)    8.6
# 2   4  Afghanistan  2013  Current health expenditure (% of GDP)    8.8
# 3   4  Afghanistan  2014  Current health expenditure (% of GDP)    9.7
# 4   4  Afghanistan  2015  Current health expenditure (% of GDP)   10.3

# %%
GDP = pd.read_csv("GDP_and_GDP_Per_Capita.csv", encoding ="ISO-8859-1")
gdp = GDP.loc[GDP.Series == "GDP per capita (US dollars)"]

# %%
energy = pd.read_csv("Production_Trade_and_Supply_of_Energy.csv", encoding ="ISO-8859-1" )
energy = energy.loc[energy.Series == "Primary energy production (petajoules)"]

# %%
internet = pd.read_csv("Internet_Usage.csv", encoding ="ISO-8859-1" )

# %%
education = pd.read_csv("Public_Expenditure_on_Education.csv", encoding ="ISO-8859-1" )
education.loc[education.Series == 'Current expenditure other than staff compensation as % of total expenditure in public institutions (%)']
education = education.loc[education.Series == "Public expenditure on education (% of government expenditure)"]

# %%
tourism = pd.read_csv("Tourist_Visitors_Arrival_and_Expenditure.csv", encoding ="ISO-8859-1" )
tourism = tourism.loc[tourism.Series == "Tourism expenditure (millions of US dollars)"]

# %%
technology = pd.read_csv("GDP_on_R&D.csv", encoding ="ISO-8859-1" )
tech = technology.loc[technology.Series == 'Gross domestic expenditure on R & D: as a percentage of GDP (%)']

# %%
rates = pd.read_csv("Exchange_Rates.csv", encoding ="ISO-8859-1" )
rates = rates.loc[rates.Series == "Exchange rates: period average (national currency per US dollar)"]

# %%
gdp.pivot(index = "Year", columns = "Country", values = "Value").head()
# Out:
# Country  Afghanistan  Albania  Algeria  Andorra  Angola  Anguilla  \
# Year
# 1985           282.0    783.0   2564.0   9837.0   859.0    4072.0
# 1995           189.0    770.0   1452.0  23359.0   466.0   10583.0
# 2005           264.0   2615.0   3100.0  41281.0  1891.0   18129.0
# 2010           558.0   4056.0   4463.0  39734.0  3586.0   19459.0
# 2015           611.0   3895.0   4163.0  36040.0  4171.0   22622.0
#
# Country  Antigua and Barbuda  Argentina  Armenia    Aruba    ...     \
# Year                                                         ...
# 1985                  3508.0     3144.0      NaN   6108.0    ...
# 1995                  7841.0     7993.0    426.0  16442.0    ...
# 2005                 11453.0     5125.0   1753.0  23303.0    ...
# 2010                 12175.0    10346.0   3432.0  23513.0    ...
# 2015                 13602.0    14853.0   3618.0  25796.0    ...
#
# Country  United States of America  Uruguay  Uzbekistan  Vanuatu  \
# Year
# ...

# %%
energy.pivot(index = "Year", columns = "Country", values = "Value").head()
# Out:
# Country  Afghanistan  Albania  Algeria  Andorra  Angola  Anguilla  \
# Year
# 1990            19.0     99.0   4380.0      0.0  1198.0       0.0
# 1995            16.0     43.0   4748.0      0.0  1585.0       0.0
# 2000            18.0     34.0   6556.0      0.0  1803.0       0.0
# 2005            23.0     48.0   7534.0      0.0  2934.0       0.0
# 2010            41.0     69.0   6200.0      1.0  4085.0       0.0
#
# Country  Antigua and Barbuda  Argentina  Armenia  Aruba    ...     \
# Year                                                       ...
# 1990                     NaN     2064.0      NaN    0.0    ...
# 1995                     NaN     2722.0     10.0    0.0    ...
# 2000                     NaN     3404.0     27.0    5.0    ...
# 2005                     NaN     3609.0     36.0    5.0    ...
# 2010                     0.0     3343.0     52.0    5.0    ...
#
# Country  United States Virgin Islands  United States of America  Uruguay  \
# Year
# ...

# %%
education.pivot(index = "Year", columns = "Country", values = "Value").head()
# Out:
# Country  Afghanistan  Albania  Algeria  Andorra  Angola  Antigua and Barbuda  \
# Year
# 2000             NaN      NaN      NaN      NaN     NaN                  NaN
# 2001             NaN      NaN      NaN      NaN     NaN                  NaN
# 2002             NaN      NaN      NaN      NaN     NaN                 11.7
# 2003             NaN      NaN      NaN      NaN     NaN                  NaN
# 2004             NaN      NaN      NaN      NaN     NaN                  NaN
#
# Country  Argentina  Armenia  Aruba  Australia    ...     United Kingdom  \
# Year                                             ...
# 2000           NaN      NaN    NaN       13.4    ...                NaN
# 2001           NaN      NaN    NaN        NaN    ...                NaN
# 2002           NaN      NaN    NaN        NaN    ...                NaN
# 2003           NaN      NaN    NaN        NaN    ...                NaN
# 2004          15.2      NaN    NaN        NaN    ...                NaN
#
# ...

# %%
tourism.pivot(index = "Year", columns = "Country", values = "Value").head()
# Out:
# Country  Afghanistan  Albania  Algeria  Angola  Anguilla  Antigua and Barbuda  \
# Year
# 1995             NaN     70.0      NaN    27.0      50.0                247.0
# 2005             NaN    880.0    477.0   103.0      86.0                309.0
# 2010           147.0   1778.0    324.0   726.0      99.0                298.0
# 2015            87.0   1613.0    347.0  1171.0     142.0                805.0
# 2016            69.0   1820.0    246.0   628.0     143.0                804.0
#
# Country  Argentina  Armenia   Aruba  Australia    ...     \
# Year                                              ...
# 1995        2550.0     14.0   554.0    10370.0    ...
# 2005        3209.0    243.0  1097.0    19719.0    ...
# 2010        5605.0    694.0  1254.0    31064.0    ...
# 2015        5441.0    956.0  1664.0    30872.0    ...
# 2016        5186.0    988.0  1632.0    36786.0    ...
#
# Country  United States Virgin Islands  United States of America  Uruguay  \
# Year
# ...

# %%
internet.pivot(index = "Year", columns = "Country", values = "Value").head()
# Out:
# Country  Afghanistan  Albania  Algeria  Andorra  Angola  Anguilla  \
# Year
# 2000             NaN      0.1      0.5     10.5     0.1      22.4
# 2005             1.2      6.0      5.8     37.6     1.1      29.0
# 2010             4.0     45.0     12.5     81.0     2.8      49.6
# 2014             7.0     60.1     29.5     95.9    10.2      70.4
# 2015             8.3     63.3     38.2     96.9    12.4      76.0
#
# Country  Antigua and Barbuda  Argentina  Armenia  Aruba    ...     \
# Year                                                       ...
# 2000                     6.5        7.0      1.3   15.4    ...
# 2005                    27.0       17.7      5.3   25.4    ...
# 2010                    47.0       45.0     25.0   62.0    ...
# 2014                    67.8       64.7     54.6   83.8    ...
# 2015                    70.0       68.0     59.1   88.7    ...
#
# Country  United States of America  Uruguay  Uzbekistan  Vanuatu  \
# Year
# ...

# %%
tech.pivot(index = "Year", columns = "Country", values = "Value").head()
# Out:
# Country  Albania  Algeria  American Samoa  Argentina  Armenia  Australia  \
# Year
# 2000         NaN      NaN             NaN        NaN      NaN        NaN
# 2001         NaN      NaN             NaN        NaN      NaN        NaN
# 2002         NaN      NaN             NaN        NaN      NaN        NaN
# 2003         NaN      NaN             NaN        NaN      NaN        NaN
# 2004         NaN      NaN             NaN        NaN      NaN        1.9
#
# Country  Austria  Azerbaijan  Bahrain  Belarus   ...    United Arab Emirates  \
# Year                                             ...
# 2000         NaN         NaN      NaN      NaN   ...                     NaN
# 2001         NaN         NaN      NaN      NaN   ...                     NaN
# 2002         NaN         NaN      NaN      NaN   ...                     NaN
# 2003         NaN         NaN      NaN      NaN   ...                     NaN
# 2004         2.2         NaN      NaN      NaN   ...                     NaN
#
# ...

# %%
rates.pivot("Year", columns = "Country", values = "Value").head()
# Out:
# Country Afghanistan Albania Algeria Andorra Angola Anguilla  \
# Year
# 1985           39.3    None       5    None      0      2.7
# 1995           36.6    92.7    47.7    None      0      2.7
# 2005           49.5    99.9    73.3     0.8   87.2      2.7
# 2010           46.5   103.9    74.4     0.8   91.9      2.7
# 2014           57.3   105.5    80.6     0.8   98.3      2.7
#
# Country Antigua and Barbuda Argentina Armenia Aruba      ...      Uruguay  \
# Year                                                     ...
# 1985                    2.7         0    None  None      ...          0.1
# 1995                    2.7         1   405.9   1.8      ...          6.4
# 2005                    2.7       2.9   457.7   1.8      ...         24.5
# 2010                    2.7       3.9   373.7   1.8      ...         20.1
# 2014                    2.7       8.1   415.9   1.8      ...         23.3
#
# Country Vanuatu Venezuela (Boliv. Rep. of)   Viet Nam  \
# Year
# ...

# %%
np.random.seed(1000)
ids = GDP.ID.unique()
print(ids.shape)  # unique country IDs

samples = np.random.choice(ids, 50)
samples # randomly selected country IDs

s = gdp.loc[gdp.ID.isin(samples),]
names = s.Country.unique()
names
# Out:
# (214,)
# array(['Albania', 'Argentina', 'Austria', 'Bahrain', 'Bermuda', 'Brazil',
#        'Burkina Faso', 'Cayman Islands', 'China', 'China, Macao SAR',
#        'Congo', 'Cuba', 'Dominica', 'Egypt', 'Finland',
#        'French Polynesia', 'Germany', 'Iceland', 'India', 'Indonesia',
#        'Ireland', 'Italy', 'Kiribati', 'Latvia', 'Malawi', 'Morocco',
#        'Nicaragua', 'Pakistan', 'Paraguay', 'Republic of Moldova',
#        'Russian Federation', 'Saint Kitts and Nevis', 'Seychelles',
#        'Singapore', 'Spain', 'Sri Lanka', 'Tajikistan', 'Thailand',
#        'Tonga', 'United States of America', 'Uruguay', 'Yemen',
#        'Zimbabwe'], dtype=object)

# %%
CPI = CPI.pivot(index = "Year", columns = "Country", values = "Value")
GDP = gdp.pivot(index = "Year", columns = "Country", values = "Value")
energy = energy.pivot(index = "Year", columns = "Country", values = "Value")
health = health.pivot(index = "Year", columns = "Country", values = "Value")
education = education.pivot(index = "Year", columns = "Country", values = "Value")
tech = tech.pivot(index = "Year", columns = "Country", values = "Value")
internet = internet.pivot(index = "Year", columns = "Country", values = "Value")
rates = rates.pivot(index = "Year", columns = "Country", values = "Value")
tourism = tourism.pivot(index = "Year", columns = "Country", values = "Value")

# %%
table = pd.DataFrame(CPI.loc[:, names[0]])
table = table.join(pd.DataFrame(GDP.loc[:, names[0]]), lsuffix='CPI', rsuffix='GDP')
table = table.join(pd.DataFrame(energy.loc[:, names[0]]), lsuffix='GDP', rsuffix='Energy')
table = table.join(pd.DataFrame(tech.loc[:, names[0]]), lsuffix = "Energy", rsuffix='Tech')
table = table.join(pd.DataFrame(education.loc[:, names[0]]), lsuffix = "Tech", rsuffix='Education')
table = table.join(pd.DataFrame(rates.loc[:, names[0]]), lsuffix = "Education", rsuffix='Rates')
table = table.join(pd.DataFrame(internet.loc[:, names[0]]), lsuffix = "Rates", rsuffix='Internet')
table = table.join(pd.DataFrame(tourism.loc[:, names[0]]), lsuffix = "Internet", rsuffix='Tourism')
table = table.join(pd.DataFrame(health.loc[:, names[0]]), lsuffix = "Tourism", rsuffix='Health')
table.fillna(method = "ffill", inplace = True)
table.fillna(method = "bfill", inplace = True)
table
# Out:
#      AlbaniaCPI  AlbaniaGDP  AlbaniaEnergy  AlbaniaTech  AlbaniaEducation  \
# Year
# 1995       40.7       770.0           43.0          NaN              11.4
# 2005       86.7      2615.0           48.0          NaN              11.4
# 2010        100      4056.0           69.0          NaN              11.4
# 2014      109.3      4056.0           85.0          NaN              11.4
# 2015      111.4      3895.0           88.0          NaN              11.3
# 2016      112.8      4061.0           82.0          NaN              11.3
# 2017      115.1      4450.0           82.0          NaN              11.3
#
#      AlbaniaRates  AlbaniaInternet  AlbaniaTourism  Albania
# Year
# 1995         92.7              6.0            70.0      6.3
# 2005         99.9              6.0           880.0      6.3
# 2010        103.9             45.0          1778.0      5.0
# 2014        105.5             60.1          1778.0      7.0
# 2015          126             63.3          1613.0      6.8
# ...

# %%
corr = table.corr()
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)
plt.show()

# %%
table1 = pd.DataFrame(CPI.loc[:, names[14]])
table1 = table1.join(pd.DataFrame(GDP.loc[:, names[14]]), lsuffix='CPI', rsuffix='GDP')
table1 = table1.join(pd.DataFrame(energy.loc[:, names[14]]), lsuffix='GDP', rsuffix='Energy')
table1 = table1.join(pd.DataFrame(tech.loc[:, names[14]]), lsuffix = "Energy", rsuffix='Tech')
table1 = table1.join(pd.DataFrame(education.loc[:, names[14]]), lsuffix = "Tech", rsuffix='Education')
table1 = table1.join(pd.DataFrame(rates.loc[:, names[14]]), lsuffix = "Education", rsuffix='rates')
table1 = table1.join(pd.DataFrame(internet.loc[:, names[14]]), lsuffix = "Rates", rsuffix='Internet')
table1 = table1.join(pd.DataFrame(tourism.loc[:, names[14]]), lsuffix = "Internet", rsuffix='Tourism')
table1 = table1.join(pd.DataFrame(health.loc[:, names[14]]), lsuffix = "Tourism", rsuffix='Health')
table1.fillna(method = "ffill", inplace = True)
table1.fillna(method = "bfill", inplace = True)
table1
# Out:
#      FinlandCPI  FinlandGDP  FinlandEnergy  FinlandTech  FinlandEducation  \
# Year
# 1995         80     26215.0          549.0          3.3              12.2
# 2005       91.2     38873.0          699.0          3.3              12.2
# 2010        100     46181.0          727.0          3.7              11.9
# 2014        109     46181.0          759.0          3.7              12.3
# 2015      108.8     42405.0          734.0          2.9              12.3
# 2016      109.2     43439.0          738.0          2.7              12.3
# 2017        110     45670.0          738.0          2.7              12.3
#
#      Finlandrates  FinlandInternet  FinlandTourism  Finland
# Year
# 1995          0.8             74.5          2383.0      8.0
# 2005          0.8             74.5          3069.0      8.0
# 2010          0.8             86.9          4497.0      8.9
# 2014          0.8             86.5          4497.0      9.5
# 2015          0.9             86.4          4009.0      9.4
# ...

# %%
corr = table1.corr()
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)
plt.show()

# %%
name = 'Russian Federation'
table2 = pd.DataFrame(CPI.loc[:, name])
table2 = table2.join(pd.DataFrame(GDP.loc[:, name]), lsuffix='CPI', rsuffix='GDP')
table2 = table2.join(pd.DataFrame(energy.loc[:, name]), lsuffix='GDP', rsuffix='Energy')
table2 = table2.join(pd.DataFrame(tech.loc[:, name]), lsuffix = "Energy", rsuffix='Tech')
table2 = table2.join(pd.DataFrame(education.loc[:, name]), lsuffix = "Tech", rsuffix='Education')
table2 = table2.join(pd.DataFrame(rates.loc[:, name]), lsuffix = "Education", rsuffix='rates')
table2 = table2.join(pd.DataFrame(internet.loc[:, name]), lsuffix = "Rates", rsuffix='Internet')
table2 = table2.join(pd.DataFrame(tourism.loc[:, name]), lsuffix = "Internet", rsuffix='Tourism')
table2 = table2.join(pd.DataFrame(health.loc[:, name]), lsuffix = "Tourism", rsuffix='Health')
table2.fillna(method = "ffill", inplace = True)
table2.fillna(method = "bfill", inplace = True)
table2
# Out:
#      Russian FederationCPI  Russian FederationGDP  Russian FederationEnergy  \
# Year
# 1995                   6.3                 2713.0                   40589.0
# 2005                  61.4                 5372.0                   50506.0
# 2010                   100                10757.0                   53679.0
# 2014                 131.2                10757.0                   55400.0
# 2015                 151.5                 9510.0                   56024.0
# 2016                 162.2                 8924.0                   57240.0
# 2017                 168.2                10956.0                   57240.0
#
#       Russian FederationTech  Russian FederationEducation  \
# Year
# 1995                     1.1                         12.0
# 2005                     1.1                         12.0
# 2010                     1.1                         12.0
# 2014                     1.1                         12.0
# ...

# %%
corr = table2.corr()
# plt.matshow(corr)
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)
plt.show()
